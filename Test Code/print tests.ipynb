# %%
print('================================='+'\nSmart Mall Parking System'+'\n================================='+'\n1. Login'+'\n2. Register'+'\n3. Exit')
# Out:
# ...
# Smart Mall Parking System
# ...
# 1. Login
# 2. Register
# 3. Exit

# %%
print(range(1,4))
# Out:
# range(1, 4)

# %%
for num in range(1,4):
    print(num)
# Out:
# 1
# 2
# 3
