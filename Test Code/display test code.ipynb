# %%
def display_function():
    #while loop to check for choice continually
    choice = 0
    while choice != 3:

        print('================================='+'\nSmart Mall Parking System'+'\n================================='+'\n1. Login'+'\n2. Register'+'\n3. Exit')
        user_input = input("Please enter your choice: ")
        #first check for strings
        if user_input.isdigit():
            choice = int(user_input)
        else:
            print('Please choose a number between 1 and 3')
            continue

        #if digit, check if 1,2,3 or anything else
        if choice == 1:
            #login.py
            print(choice)
        elif choice == 2:
            #register.py
            print(choice)

        #Check for yes and no inputs, added validation for multiple types of inputs and accidental whitespace.
        elif choice == 3:
            exit_choice = input('Are you sure you want to exit? Enter either YES or NO.')
            exit_choice = exit_choice.strip().upper()
            if exit_choice == 'YES':
                exit()
            elif exit_choice == "NO":
                choice = 0
            else:
                print('Please enter either YES or NO.')
                choice = 0

            else:
                print('Please choose a number between 1 and 3')
                choice = 0

# %%
my_function()
# Out:
# ...
# Smart Mall Parking System
# ...
# 1. Login
# 2. Register
# 3. Exit
# ...
# Smart Mall Parking System
# ...
# 1. Login
# 2. Register
# 3. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 my_function()
#
# Cell In[3], line 7, in my_function()
#       3     choice = 0
#       4     while choice != 3:
#       5
#       6         print('================================='+'\nSmart Mall Parking System'+'\n================================='+'\n1. Login'+'\n2. Register'+'\n3. Exit')
# ----> 7         user_input = int(input("Please enter your choice: "))
#       8
#       9         if user_input == 1:
#      10             choice = 1
#
# File ~\PycharmProjects\Programming-511\.venv\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
# ...
