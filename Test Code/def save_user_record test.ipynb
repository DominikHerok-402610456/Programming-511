# %%
def save_user_record(file_name,input_line):
    with open(file_name,'a') as file:
            file.write(input_line + '\n')

# %%
save_user_record('users.txt','Dom,mypassworsd,driver')

# %%
with open('users.txt','r') as file:
    contents = file.read()
    print(contents)
# Out:
# Dom,mypassword,driver
# Dom,mypassword,driver
# Dom,mypassword,driver
# Dom,mypassworsd,driver
